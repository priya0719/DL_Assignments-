# %% [markdown]
# <a href="https://colab.research.google.com/github/priya0719/DL_Assignments-/blob/main/diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
from pycaret.utils import enable_colab
enable_colab

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd 
import io
df = pd.read_csv(io.BytesIO(uploaded['diabetes_dataset_2019.csv']))
# Out:
#      <input type="file" id="files-753b1fc5-a075-4376-adfd-dd1944d92768" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-753b1fc5-a075-4376-adfd-dd1944d92768">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes_dataset_2019.csv to diabetes_dataset_2019.csv

# %%
get_ipython().system('pip install scikit-optimize')
# Out:
# ...
#      |████████████████████████████████| 100 kB 4.9 MB/s
# ...

# %%
from pycaret.classification import *
clf = setup(data= df, target ='Diabetic', session_id = 42 )
# Out:
#                                Description                  Value
# 0                               session_id                     42
# 1                                   Target               Diabetic
# 2                              Target Type             Multiclass
# 3                            Label Encoded   no: 0, no: 1, yes: 2
# 4                            Original Data              (952, 18)
# 5                           Missing Values                   True
# 6                         Numeric Features                      1
# 7                     Categorical Features                     16
# 8                         Ordinal Features                  False
# 9                High Cardinality Features                  False
# 10                 High Cardinality Method                   None
# 11                   Transformed Train Set              (665, 59)
# 12                    Transformed Test Set              (286, 59)
# ...

# %%
compare_models()
# Out:
#                                     Model  Accuracy  AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.9563  0.0  0.9382  0.9687
# rf               Random Forest Classifier    0.9534  0.0  0.9383  0.9633
# gbc          Gradient Boosting Classifier    0.9367  0.0  0.9255  0.9513
# ridge                    Ridge Classifier    0.8873  0.0  0.8860  0.9158
# lr                    Logistic Regression    0.8782  0.0  0.8799  0.9083
# knn                K Neighbors Classifier    0.8270  0.0  0.8889  0.8417
# dummy                    Dummy Classifier    0.7399  0.0  0.9333  0.7202
# ada                  Ada Boost Classifier    0.5981  0.0  0.4716  0.9027
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.9692  0.8865  0.8875     0.390
# rf        0.9668  0.8783  0.8790     0.514
# gbc       0.9541  0.8339  0.8366     0.400
# ridge     0.9166  0.7012  0.7036     0.275
# lr        0.9097  0.6751  0.6781     0.574
# knn       0.8784  0.4945  0.5120     0.120
# ...

# %%
from pycaret.classification import *
rf = create_model('rf')
plot_model(rf)''
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.9851  0.0  1.0000  0.9800  0.9899  0.9613  0.9621
# 1       0.8955  0.0  0.9184  0.9375  0.9278  0.7387  0.7392
# 2       1.0000  0.0  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9254  0.0  0.9600  0.9412  0.9505  0.7990  0.7997
# 4       0.9701  0.0  0.6471  0.9564  0.9628  0.9220  0.9247
# 5       0.9394  0.0  0.9592  0.9592  0.9592  0.8415  0.8415
# 6       0.9545  0.0  0.9796  0.9600  0.9697  0.8788  0.8795
# 7       0.9545  0.0  0.9796  0.9600  0.9697  0.8788  0.8795
# 8       0.9545  0.0  0.9592  0.9792  0.9691  0.8834  0.8841
# 9       0.9545  0.0  0.9796  0.9600  0.9697  0.8788  0.8795
# Mean    0.9534  0.0  0.9383  0.9633  0.9668  0.8783  0.8790
# SD      0.0279  0.0  0.0996  0.0177  0.0188  0.0712  0.0713
# IntProgress(value=0, description='Processing: ', max=5)
# ---------------------------------------------------------------------------
# ...
